# %%
import pandas as pd
from collections import Counter
import math

# %%
# read in the tweets
traintweets = pd.read_csv('traintweets.csv', sep='\t')
apptweets = traintweets[traintweets['Class'] == 'APP']
othertweets = traintweets[traintweets['Class'] == 'OTHER']

# drop any empty rows that are read in
apptweets = apptweets.dropna()
othertweets = othertweets.dropna()

# %%
# a function to clean up the tweets up a bit, by making them lowercase and replacing common punctuation with spaces
def cleantext(string):
    string = string.lower()
    string = string.replace(". ", " ")
    string = string.replace(": ", " ")
    string = string.replace("?"," ")
    string = string.replace("!"," ")
    string = string.replace(";", " ")
    string = string.replace(",", " ")
    return string

# %%
# apply the function to all the tweets using list comphrehension
apptweets['Tweet'] = [cleantext(i) for i in apptweets['Tweet']]
othertweets['Tweet'] = [cleantext(i) for i in othertweets['Tweet']]

# %%
othertweets
# Out:
#      Class                                              Tweet
# 0    OTHER              ¿en donde esta su remontada mandrill
# 1    OTHER  .@katie_phd alternate  'reproachful mandrill' ...
# 2    OTHER  .@theophani can i get "drill" in there  it wou...
# 3    OTHER  “@chrisjboyland baby mandrill paignton zoo 29t...
# 4    OTHER  “@missmya #nameanamazingband mandrill ” mint c...
# 5    OTHER  “fat city strut” by mandrill is my new jam htt...
# 6    OTHER   soul train #22 1973  mandrill                ...
# 7    OTHER  @alicegreennn_ but how come you didn't have ma...
# 8    OTHER  @as_tomasroncero a la mierda el mandrill tocat...
# 9    OTHER  @burnziey @sjsharkfinatic i have zach mandrill...
# 10   OTHER                  @charlie29598 #greatjob #mandrill
# 11   OTHER  @justdewyou @isma_longo tu no ables sapo que e...
# 12   OTHER  @khamili_1015 @espsmile t'es vraiment idiot co...
# 13   OTHER  @mandrill "the venue should be opening once th...
# 14   OTHER  @mandrill @ccp_manifest @ccpgames don't go to ...
# 15   OTHER  @mandrill @ccpgames i hope they record the who...
# 16   OTHER  @mandrill @ccpgames plus  we have a faint ccp ...
# 17   OTHER  @mandrill @freebooted probably try to corner t...
# 18   OTHER  @mandrill @freebooted i want to say heinlein b...
# 19   OTHER      @mandrill @hilmarveigar zomg want that jacket
# 20   OTHER  @mandrill @j_smedley is around here somewhere....
# 21   OTHER  @mandrill @kelduum @reesnoturana @webspaceship...
# 22   OTHER  @mandrill @kelduum @webspaceships @whistlerbea...
# 23   OTHER  @mandrill @whistlerbean #eveonline we totally ...
# 24   OTHER  @mandrill @yara_ash @freebooted o/ we wish you...
# 25   OTHER                     @mandrill about 5" long or so.
# 26   OTHER  @mandrill ah seen no  i meant britain actually...
# 27   OTHER  @mandrill ahh i'd have to save for 10 years to...
# 28   OTHER             @mandrill and this is why i'm here :-)
# 29   OTHER  @mandrill been trying to look up more of these...
# ..     ...                                                ...
# 118  OTHER  megaman x - spark mandrill acapella http://you...
# 119  OTHER  megaman x - spark mandrill acapella http://you...
# 120  OTHER  megaman x fans  i grace you with an incredible...
# 121  OTHER  my squad half-mandrill  half-mandela/my band r...
# 122  OTHER  nieuw in de verkoop bij hoekstra&vaneck mandri...
# 123  OTHER  one reason is out  http://paper.li/mandrill/13...
# 124  OTHER              peter mandrill son #animalcelebrities
# 125  OTHER  please help my friend kumba  the mandrill  fix...
# 126  OTHER  que caritas de gilipollas se le quedaron a los...
# 127  OTHER  raj shahrukh shogun is an immature mandrill si...
# 128  OTHER  silk by mandrill http://youtu.be/rtuyx7if6jm v...
# 129  OTHER                   spark mandrill theme #nerdatwork
# 130  OTHER                       spark mandrill  toma domecq
# 131  OTHER                stand by your mandrill #animalsongs
# 132  OTHER  straight a mandrill as looses voluptuous jump ...
# 133  OTHER  stukkie stekst geschreven over muziek voor de ...
# 134  OTHER  symphonic revolutions - mandrill http://rdo.to...
# 135  OTHER  taquipariu @jurandirfilho olha isso mega man x...
# 136  OTHER  the @tbobbymitchell 7s cartoon character is li...
# 137  OTHER  the #drill & #mandrill were originally classed...
# 138  OTHER  the two songs in my head went like this "devil...
# 139  OTHER  this little girl is a mandrill milwaukee count...
# 140  OTHER  today's music choice heavy metal cover of mega...
# 141  OTHER  ushindi the mandrill can't get enough of the s...
# 142  OTHER                vamos atleti     puta mandrill
# 143  OTHER  why are monkey butts so colorful  mandrill wik...
# 144  OTHER  you can now experience the thrills of classic ...
# 145  OTHER               mandrill 75        oddisee       ...
# 146  OTHER                                 b1   80        ...
# 147  OTHER      nottz feat pete rock / turn it up         ...
#
# [148 rows x 2 columns]

# %%
# create two Counter objects to keep track of the number of times any token shows up in each dataset
appcnt = Counter()
othercnt = Counter()

# iterate through both dataframes, splitting the Tweet into separate words, and using the Counter objects to sum up the
# frequencies of the tokens
for index, row in apptweets.iterrows():
    for word in row.Tweet.split(' '):
        appcnt[word] += 1

for index, row in othertweets.iterrows():
    for word in row.Tweet.split(' '):
        othercnt[word] += 1

# %%
# copy the two previous Counter objects; this allows us to change them while iterating through the originals
appcntclean = appcnt.copy()
othercntclean = othercnt.copy()

# %%
othercnt['remontada']
# Out:
# 1

# %%
# delete any tokens that are less than 4 characters in length
for i in appcnt:
    if len(i) <= 3:
        del appcntclean[i]
        
for i in othercnt:
    if len(i) <= 3:
        del othercntclean[i]

# %%
# add 1 to every token count, this is Additive Smoothing (Laplace Smoothing)
# this ensures that later on, if we encounter a word, we can act like we saw it once before
# so we add one to every other token to account for that, and give them more weight
for i in appcntclean:
    appcntclean[i] = appcnt[i] + 1
    
for i in othercntclean:
    othercntclean[i] = othercnt[i] + 1

# %%
appcnt['simple']
# Out:
# 1

# %%
appcnt['api']
# Out:
# 9

# %%
appcntclean
# Out:
# Counter({'#atl': 2,
#          '#atlanta': 2,
#          '#bjcbranding': 2,
#          '#buddypress': 2,
#          '#career': 2,
#          '#design': 2,
#          '#dev': 2,
#          '#drupal': 4,
#          '#edocr': 2,
#          '#eecms': 3,
#          '#enginehosting': 2,
#          '#freelance': 8,
#          '#freelancer': 2,
#          '#howto': 2,
#          '#integration': 2,
#          '#internetmarketing': 2,
#          '#interspire': 3,
#          '#javascript': 4,
#          '#job': 8,
#          '#jobs': 5,
#          '#jobs4u': 2,
#          '#jquery': 3,
#          '#lightweight': 2,
#          '#linux': 2,
#          '#logo': 2,
#          '#mandrill': 4,
#          '#mysql': 2,
#          '#newsletters': 2,
#          '#photoshopdesign': 2,
#          '#php': 4,
#          '#plone': 3,
#          '#plugin': 2,
#          '#plugins': 2,
#          '#project': 2,
#          '#python': 2,
#          '#redhen': 2,
#          '#selfinducedcannibalization': 2,
#          '#sendgrid': 2,
#          '#templates': 2,
#          '#timetomoveon': 2,
#          '#transactional': 2,
#          '#wcmelb': 3,
#          '#wordpress': 3,
#          '(0.0.3)': 2,
#          '(0.0.4)': 2,
#          '(1.0.19)': 2,
#          '(1.0.25)': 2,
#          '(@mandrillapp)': 2,
#          '(confirmação': 2,
#          '(http://j.mp/10tohxc': 2,
#          '(http://j.mp/10tohxg': 2,
#          '(i.e': 2,
#          '(ils': 2,
#          '(line': 2,
#          '(one-to-one': 2,
#          '(some': 2,
#          '(their': 2,
#          '1.0.22': 2,
#          '1.0.29': 2,
#          '3rd-party': 2,
#          '@aalbertson': 2,
#          '@abhijeetmk': 2,
#          '@adrienneleigh': 2,
#          '@ankeshk': 2,
#          '@biggoldring': 2,
#          '@bluehayes': 2,
#          '@camj59': 6,
#          '@cemsisman': 2,
#          '@chrislema': 6,
#          '@compactcode': 2,
#          '@devongovett': 4,
#          '@drupalplanet': 2,
#          '@dzuelke': 3,
#          '@edocr': 2,
#          '@eladlouni': 4,
#          '@elie__': 3,
#          '@ericcandino': 2,
#          '@flo_rian': 2,
#          '@frankioh': 2,
#          '@freedomwalker77': 2,
#          '@gidogeek': 2,
#          '@guillaumepotier': 2,
#          '@henrik': 2,
#          '@hiway': 2,
#          '@icntmx': 2,
#          '@jeremyweir': 2,
#          '@josscrowcroft': 2,
#          '@juanpabloaj': 2,
#          '@kanonbulle': 2,
#          '@kennydude': 2,
#          '@kennyfraser': 2,
#          '@khiger': 2,
#          '@levelos': 2,
#          '@ljharb': 2,
#          '@mailchimp': 5,
#          "@mailchimp's": 3,
#          '@mailjet': 2,
#          '@mandrill': 3,
#          '@mandrillapp': 14,
#          '@manojranaweera': 2,
#          '@marcelosomers': 2,
#          '@masuga': 2,
#          '@matt_pickett': 2,
#          '@mattwdelong': 2,
#          '@meeiw': 2,
#          '@michaelmior': 2,
#          '@mnordin': 2,
#          '@myshoggoth)': 2,
#          '@nathanbowser': 2,
#          '@nathansmith': 3,
#          '@reevesman': 2,
#          '@reubenpressman': 2,
#          '@richaskew': 2,
#          '@rodbegbie': 2,
#          '@rossdeane': 2,
#          '@sampad': 2,
#          '@sanjubhambhani': 2,
#          '@sendgrid': 5,
#          '@sinue': 4,
#          '@tamiyadd': 2,
#          '@thatmarvin': 2,
#          '@tinyletter': 2,
#          '@traskjd': 2,
#          '@treize2': 2,
#          '@variuxdavid': 2,
#          '@veroapp': 2,
#          '@webplatform': 2,
#          '@wesbos': 2,
#          '[blog]': 3,
#          'able': 2,
#          'about': 10,
#          'access': 2,
#          'account': 9,
#          'activity': 2,
#          'adding': 2,
#          'additional': 4,
#          'addresses': 2,
#          'admon': 2,
#          'affair': 2,
#          'after': 3,
#          'aggregate': 2,
#          'algorithm': 2,
#          'all.': 2,
#          'already': 4,
#          'alternate': 2,
#          'alternatives': 2,
#          'amazon': 2,
#          'among': 2,
#          'animal': 2,
#          'any)': 2,
#          'anyone': 4,
#          'aperturas': 2,
#          'api.': 2,
#          'app.': 2,
#          'application': 2,
#          'approach': 2,
#          'apps': 2,
#          'apps)': 2,
#          'ar..': 2,
#          'area': 2,
#          'array': 2,
#          'arrays': 2,
#          'article': 2,
#          'atau': 2,
#          'attention': 2,
#          'auth': 2,
#          'automático': 2,
#          'automáticos': 2,
#          'autoplay': 2,
#          'available': 2,
#          'avec': 3,
#          'avoid': 2,
#          'awesome': 2,
#          'back': 2,
#          'base': 2,
#          'based': 2,
#          'been': 4,
#          'before': 2,
#          'best': 2,
#          'best..': 2,
#          'beware': 2,
#          'biased': 2,
#          'bien': 3,
#          'blocked': 2,
#          'blog': 3,
#          'both': 2,
#          'bounce': 7,
#          'brainstorm': 2,
#          'bring': 2,
#          'buat': 2,
#          'bugs': 2,
#          'building': 2,
#          'built': 2,
#          'bulk': 2,
#          'bullhorn': 2,
#          'bylo': 2,
#          'called': 2,
#          'cannibaliser..': 2,
#          'cannot': 2,
#          'captcha': 2,
#          'chance': 2,
#          'change': 2,
#          'changes': 2,
#          'cheap': 2,
#          'check': 3,
#          'checked': 2,
#          'cheetah': 2,
#          'cher': 4,
#          'chez': 2,
#          'cleaned': 2,
#          'click': 2,
#          'client': 5,
#          'clients': 2,
#          'cloud': 2,
#          'come': 2,
#          'comparé': 2,
#          'competing': 2,
#          'competitor)': 2,
#          'computing': 2,
#          'concern': 2,
#          'confusing': 2,
#          'considerably': 2,
#          'contact': 2,
#          'cool': 2,
#          'correct': 2,
#          'could': 2,
#          'couple': 2,
#          'coworker': 2,
#          'crashes': 2,
#          'crashing': 2,
#          'critsend': 2,
#          'currently': 3,
#          'custom': 2,
#          'customer-support': 2,
#          'customized': 2,
#          "d'amazon": 2,
#          'darn': 2,
#          'data': 3,
#          'debug.': 2,
#          'decreases': 2,
#          'defaults': 2,
#          'delisted': 2,
#          'delivering': 2,
#          'delivery': 2,
#          'depende': 2,
#          'depends': 2,
#          'design': 10,
#          'designed': 2,
#          'designer': 2,
#          'detail': 6,
#          'details': 14,
#          'develop': 2,
#          'developer': 2,
#          'developers': 2,
#          'devs': 2,
#          'dices': 2,
#          "didn't": 2,
#          'digitalocean': 2,
#          'directly': 2,
#          'dishes': 2,
#          "disney's": 2,
#          'dist': 2,
#          'docs': 2,
#          'documenting': 2,
#          'does': 3,
#          'domain': 2,
#          'domains': 2,
#          "don't": 2,
#          'done': 2,
#          'drop': 2,
#          'dropped': 2,
#          'drupal': 4,
#          'dumped': 2,
#          'e-mail': 2,
#          'e-mails': 3,
#          'easily.': 2,
#          'easy': 2,
#          'ecommerce': 4,
#          'edocr.co..': 2,
#          'either': 2,
#          'elance': 2,
#          'email': 27,
#          'email.': 2,
#          'emails': 11,
#          'emails..': 2,
#          'emails/mo': 2,
#          'enakan': 2,
#          'engagement': 2,
#          "engine's": 2,
#          'enquiring': 2,
#          'entrust': 2,
#          'envio': 2,
#          'equivalente': 2,
#          'error': 2,
#          'error(s)': 2,
#          'escort': 2,
#          'eshuys': 10,
#          'esqueci': 2,
#          'esta': 2,
#          'estimated': 2,
#          'even': 2,
#          'every': 2,
#          'everyone': 2,
#          'everything': 2,
#          'exactly': 2,
#          'examples': 2,
#          'excellently.': 2,
#          'exemple..': 2,
#          'experience': 2,
#          'facile': 2,
#          'favor': 2,
#          'ferramenta': 2,
#          'fiasco': 2,
#          'fica': 2,
#          'find': 3,
#          'fixes)': 2,
#          'fois': 2,
#          'found': 2,
#          'free': 3,
#          'friday': 2,
#          'from': 9,
#          'fwiw': 2,
#          'geek': 2,
#          'general': 3,
#          'gets': 2,
#          'getting': 2,
#          'give': 4,
#          'glad': 4,
#          'gmail': 2,
#          'goes': 2,
#          'good': 4,
#          'google': 2,
#          'gosh': 2,
#          'green': 2,
#          'grid': 4,
#          'guys': 2,
#          'gérer': 2,
#          'ha..': 2,
#          'had..': 3,
#          'handling': 2,
#          'hard': 2,
#          'have': 18,
#          'have..': 2,
#          "haven't": 3,
#          'header': 2,
#          'heads': 2,
#          'hear': 2,
#          'help': 5,
#          'here': 5,
#          'highly': 2,
#          'hitting': 2,
#          'holy': 2,
#          'homepage)': 2,
#          'hooray': 2,
#          'hotmail': 2,
#          'http://adf.ly/m0jic': 2,
#          'http://awe.sm/eebz1': 2,
#          'http://awe.sm/r0jhw': 2,
#          'http://bit.ly/1035kio': 2,
#          'http://bit.ly/10couon': 2,
#          'http://bit.ly/10jzwtc': 2,
#          'http://bit.ly/10wbvdy': 2,
#          'http://bit.ly/118used': 3,
#          'http://bit.ly/118ybvg': 2,
#          'http://bit.ly/11hmdzz': 2,
#          'http://bit.ly/11htha9': 2,
#          'http://bit.ly/123hnfe': 2,
#          'http://bit.ly/125h1bh': 2,
#          'http://bit.ly/12r8ush': 2,
#          'http://bit.ly/12thlly': 2,
#          'http://bit.ly/13uja7s': 2,
#          'http://bit.ly/13wau5c': 2,
#          'http://bit.ly/148jf4m': 2,
#          'http://bit.ly/14myvuh': 2,
#          'http://bit.ly/160nkq3': 2,
#          'http://bit.ly/161vnvj': 2,
#          'http://bit.ly/18d2end': 2,
#          'http://bit.ly/untj4n': 2,
#          'http://bit.ly/xg24ek': 2,
#          'http://bit.ly/xrahys': 2,
#          'http://bit.ly/xy4vjw': 2,
#          'http://bit.ly/yh6xht': 2,
#          'http://bit.ly/yh7qtf': 2,
#          'http://bit.ly/yo8iuu': 2,
#          'http://bit.ly/z0ibzm': 2,
#          'http://bit.ly/z5e5wa': 2,
#          'http://bit.ly/zawi4i': 2,
#          'http://bit.ly/zjhok7': 2,
#          'http://bit.ly/zmrcsz': 2,
#          'http://bit.ly/ztadzb': 2,
#          'http://bit.ly/ztbptb': 2,
#          'http://bit.ly/ztbpwt': 2,
#          'http://blog.mailchimp.com/unifying-mandrill-and-mailchimp-data/': 2,
#          'http://blog.mandrill.com': 2,
#          'http://blog.mandrill.com/broader-templates-quota-control.html': 2,
#          'http://blog.mandrill.com/friday-notes-2013-03-08.html': 2,
#          'http://blog.mandrill.com/new-simpler-pricing.html': 2,
#          'http://buff.ly/xw8ezx': 2,
#          'http://clema.cc/zet0l3': 2,
#          'http://devot-ee.com/add-ons/escort': 2,
#          'http://dzone.com/dwqf': 2,
#          'http://eepurl.com/odbf5': 2,
#          'http://eepurl.com/xthgx': 2,
#          'http://goo.gl/bywbf': 3,
#          'http://goo.gl/fb/6gxm3': 2,
#          'http://goo.gl/fb/xoppn': 2,
#          'http://goo.gl/kmgdg': 2,
#          'http://goo.gl/qagx2': 2,
#          'http://help.mandrill.com': 23,
#          'http://help.mandrill.com/entries/21688056-using-smtp-headers-to-customize-your-messages': 2,
#          'http://help.mandrill.com/entries/21738467-using-mandrill-s-smtp-integration-with-web-frameworks': 2,
#          'http://help.mandrill.com/entries/22092308-what-is-the-format-of-inbound-email-webhooks': 2,
#          'http://help.mandrill.com/forums/20689696-smtp-integration': 2,
#          'http://ht.ly/2wtd1t': 2,
#          'http://instagram.com/p/x-m_wcxta7/': 2,
#          'http://is.gd/ltn1ay': 2,
#          'http://is.gd/nobije': 2,
#          'http://is.gd/wkfryo': 2,
#          'http://jsfiddle.net/mandrill/gawtw/2/': 2,
#          'http://jsfiddle.net/mandrill/gawtw/4/': 2,
#          'http://jsfiddle.net/mandrill/k8ebe/3/': 2,
#          'http://jsfiddle.net/mandrill/wltns/5/': 2,
#          'http://mandrill.com': 7,
#          'http://mandrill.com/': 5,
#          'http://npmjs.org/package/mandrill-api': 2,
#          'http://ow.ly/jjadg': 2,
#          'http://pyq.io/so/16260022': 2,
#          'http://www.freewebsitereport.org/www.mandrill.com': 2,
#          'http://www.mandrill.com': 2,
#          'http://www.mandrill.com/': 3,
#          'https://github.com/aceofspades/sendgrid_postback': 2,
#          'https://github.com/fabiancz/mandrill-nette/commit/d3eb22c0ca99651a7abfc380d7b47253bbb4832e': 2,
#          'https://longreply.com/r/1445d273': 2,
#          'https://longreply.com/r/2f58968b': 2,
#          'https://longreply.com/r/5c31a7d7': 2,
#          'https://longreply.com/r/66c91ea4': 2,
#          'https://longreply.com/r/8c906b44': 2,
#          'https://www.evernote.com/shard/s9/sh/f6377f27-aa93-48f4-a9dc-4b10adfdf43f/dec196d3e531c3dfff1ceaed8a21452c/res/bc74b49c-e724-4b29-abfb-cb82032732c0/skitch.png': 2,
#          'hummingbirds': 2,
#          'håller': 2,
#          "i've": 2,
#          'idea': 2,
#          'ideas': 2,
#          'idem': 2,
#          'implementation': 10,
#          'impressed': 2,
#          'improve': 2,
#          'inappropriate': 2,
#          'inbound': 2,
#          'including': 2,
#          'increases': 2,
#          'increasing': 2,
#          'info': 3,
#          'information': 2,
#          'inline': 2,
#          'inlining': 2,
#          'inte..': 2,
#          'integrate': 5,
#          'integrated': 2,
#          'integratio': 2,
#          'integration': 9,
#          'interacting': 2,
#          'internet-marketing': 2,
#          'intersp..': 2,
#          'interspire': 4,
#          'into': 2,
#          'investigate': 2,
#          "isn't": 2,
#          'issues': 9,
#          "it's": 2,
#          'it’s': 2,
#          'joke': 2,
#          'jparle': 2,
#          'jungle': 2,
#          'just': 12,
#          'kate281': 4,
#          'kingdom': 2,
#          'know': 3,
#          'knowledge': 2,
#          "l'email": 2,
#          'lack': 2,
#          'last': 3,
#          "let's": 2,
#          'library': 4,
#          'light': 2,
#          'lik..': 2,
#          'like': 6,
#          'line': 2,
#          'link': 2,
#          'linode': 2,
#          'linux': 3,
#          'list': 2,
#          'listas': 2,
#          'listes': 2,
#          'listing..': 2,
#          'lite': 2,
#          'live': 3,
#          'login': 3,
#          'logo': 2,
#          'look': 6,
#          'look.': 2,
#          'looked': 2,
#          'looking': 9,
#          'looks': 2,
#          'lost': 2,
#          'love': 3,
#          'mail': 5,
#          'mail.': 2,
#          'mailchimp': 16,
#          "mailchimp's": 3,
#          'mailchimp)': 2,
#          'mailchimp/mandrill': 2,
#          'mailchip': 2,
#          'mailgun/mandrill': 2,
#          'mailjet': 2,
#          'mais': 2,
#          'make': 2,
#          'makes': 2,
#          'maldito': 2,
#          'mamp': 2,
#          'manage': 2,
#          'management': 2,
#          'mande': 2,
#          'mandrill': 95,
#          'mandrill-api': 3,
#          'mandrill-rails': 2,
#          'mandrill..': 2,
#          'mandrill’s': 2,
#          'marketing': 4,
#          'marks': 2,
#          'meant': 2,
#          'measuring': 2,
#          'message': 3,
#          'method': 2,
#          'might': 2,
#          'million': 3,
#          'mind': 12,
#          'mo..': 2,
#          'module': 2,
#          'modules': 5,
#          'moins': 2,
#          'mois': 2,
#          'more': 6,
#          'move': 2,
#          'much': 2,
#          'neat': 2,
#          'necesites': 2,
#          'need': 4,
#          'needed': 4,
#          'newsletters': 11,
#          'nice': 2,
#          'nice.': 2,
#          'no:)': 2,
#          'notes': 2,
#          'noticed': 2,
#          'notifications': 2,
#          'notificações...)': 2,
#          'nullmailer': 3,
#          'occur': 2,
#          'offer': 2,
#          'official': 3,
#          'one-to-one': 2,
#          'only': 2,
#          'option': 2,
#          'options': 2,
#          'other': 2,
#          'outboud': 3,
#          'over': 3,
#          'overall': 2,
#          'owner': 2,
#          'p/emails': 2,
#          'p/mkt': 2,
#          'page': 5,
#          'para': 4,
#          'parler': 2,
#          'parse': 2,
#          'parse-powered': 2,
#          'partners': 2,
#          'pas..': 2,
#          'password': 2,
#          'payment': 2,
#          'pedindo': 2,
#          'pela': 2,
#          'performance': 2,
#          'permettent': 2,
#          'photo': 2,
#          'pic.twitter.com/9oeguxgj4t': 2,
#          'plans': 2,
#          'platform': 4,
#          'platform.': 2,
#          'plus': 2,
#          'point': 2,
#          'pokemon".': 2,
#          'portion': 2,
#          'possibly': 2,
#          'postageapp': 2,
#          'posted': 2,
#          'postfix': 2,
#          'postman': 2,
#          'postmark': 2,
#          'power': 2,
#          'preferred': 2,
#          'pretty': 2,
#          'prices': 2,
#          'pricing': 6,
#          'prioritization': 2,
#          'probably': 3,
#          'processing': 6,
#          'product': 3,
#          'product.': 2,
#          'production': 2,
#          'profile': 2,
#          'progress': 2,
#          'properties': 2,
#          'provisioning': 2,
#          'psyched': 2,
#          'push': 3,
#          'pushing': 2,
#          'python': 3,
#          'question': 3,
#          'quick': 2,
#          'quota': 2,
#          'radsi': 2,
#          'rafiki': 2,
#          'rails': 2,
#          'raison': 2,
#          'reach': 2,
#          'ready': 2,
#          'realised': 2,
#          'really': 2,
#          'reasons': 3,
#          'recommendation++': 2,
#          'recommended': 2,
#          'reduced': 2,
#          'refreshing': 2,
#          'relai': 2,
#          'release': 2,
#          'released': 2,
#          'request': 17,
#          'resets': 2,
#          'review': 2,
#          'rock': 2,
#          'ruby': 3,
#          'runs': 2,
#          'sale': 2,
#          'same': 3,
#          'sans': 2,
#          'sanu1255': 4,
#          'sanu1255…': 2,
#          'saving': 2,
#          'scalability': 2,
#          'secondary': 2,
#          'seconds': 2,
#          'seeing': 5,
#          'seem': 2,
#          'seems': 5,
#          'send': 14,
#          'send/receive': 2,
#          'sendgrid': 14,
#          'sending': 6,
#          'sendmail': 2,
#          'sengrid': 3,
#          'senha': 2,
#          'sent': 2,
#          'sent.': 2,
#          'server': 4,
#          'service': 12,
#          'services': 4,
#          'settings': 2,
#          'several': 3,
#          'sexual': 2,
#          'share': 2,
#          'shit': 2,
#          'should': 3,
#          'simple': 2,
#          'simplified': 2,
#          'sistema': 2,
#          'sistemas': 2,
#          'site': 2,
#          'själv': 2,
#          'smtp': 8,
#          'solution': 2,
#          'some': 9,
#          'sorry': 2,
#          'sort': 2,
#          'sous': 2,
#          'spam': 3,
#          'spat': 2,
#          'specifically': 2,
#          'speed': 2,
#          'spotless': 2,
#          'stage': 2,
#          'stand': 2,
#          'started': 2,
#          'stats': 2,
#          'status': 2,
#          'store': 4,
#          'straightened': 2,
#          'strategy': 10,
#          'submit': 7,
#          'submitting': 11,
#          'subscriber': 2,
#          'success': 2,
#          'suggestions': 2,
#          'sunzi.': 2,
#          'support': 5,
#          'sure': 2,
#          'swapping': 2,
#          'switch': 4,
#          'switched': 2,
#          'sync': 2,
#          'system': 2,
#          'tah-dah': 2,
#          'take': 3,
#          'tal.': 2,
#          'talk': 2,
#          'team': 4,
#          'tell': 2,
#          'template': 11,
#          'testar': 2,
#          'thanks': 2,
#          'that': 9,
#          "that's": 2,
#          'their': 2,
#          'then': 2,
#          'there': 13,
#          "there's": 2,
#          'these': 2,
#          'they': 2,
#          "they're": 2,
#          'things': 2,
#          'thingy': 2,
#          'thinking': 2,
#          'this': 10,
#          'throttling': 3,
#          'timeline': 2,
#          'tiny': 2,
#          'tinyletter)': 2,
#          'tips': 2,
#          'tittat': 2,
#          'tomorrow': 2,
#          'traffic': 2,
#          'transaccionales': 2,
#          'transaction': 2,
#          'transactional': 12,
#          'transactionnel': 2,
#          'transport': 2,
#          'trapny': 2,
#          'tried': 2,
#          'triggered': 2,
#          'troubleshoot': 2,
#          'trying': 2,
#          'tsypin': 3,
#          'tuer': 2,
#          'ubuntu': 4,
#          'un..': 2,
#          'unfortunately': 2,
#          'unifying': 3,
#          'unraveled': 4,
#          'unsubscribed': 2,
#          'unsupported': 2,
#          'updates': 3,
#          'urlfetch': 2,
#          'used': 2,
#          'useful': 2,
#          'username': 3,
#          'users': 2,
#          'using': 12,
#          'utm_source=devcircle&utm_medium=banner&utm_campaign=carbon': 2,
#          'validationerror': 2,
#          'vary': 2,
#          'vero': 2,
#          'very': 4,
#          'veulent': 3,
#          'volume': 2,
#          'volumes': 2,
#          'want': 5,
#          'wanted': 2,
#          'warmup': 2,
#          'warning': 2,
#          "we'd": 3,
#          "we'll": 3,
#          "we're": 4,
#          "we've": 4,
#          'webhooks': 7,
#          'website': 3,
#          'week': 4,
#          "week's": 2,
#          'welcome': 2,
#          'well': 4,
#          'we’re': 2,
#          'whaaat': 2,
#          'what': 11,
#          "what's": 2,
#          'when': 4,
#          'where': 4,
#          'which': 2,
#          'whom': 2,
#          'wisest': 2,
#          'with': 37,
#          'wordpress': 7,
#          'words': 2,
#          'workflow': 2,
#          'working': 3,
#          'works': 2,
#          'world': 2,
#          'worth': 4,
#          'would': 6,
#          'wp_mail()': 2,
#          'yeah': 2,
#          'yeap': 2,
#          'year': 2,
#          'yep.': 2,
#          "you'd": 2,
#          "you'll": 2,
#          "you're": 7,
#          'your': 12,
#          'zapier': 2,
#          'ótima': 2,
#          '‘migrate’': 2,
#          '“mandrill”': 2})

# %%
# create two dict objects to contain the probabilities of the words given that they are an app tweet or other tweet
probapp = {}
probother = {}

# add in the logged probabilities into the dict for each respective dataset, the probability being:
# (count of how many times we've seen this token)/(count of all the times we've seen all tokens)
# we log them so we don't run into the floating point underflow error when trying to multiply together many small probablities
# instead by logging them we can just add them since log(a*b) = log(a) + log(b)
for i in appcntclean:
    probapp[i] = math.log(float(appcntclean[i])/sum(appcntclean.values()))

for i in othercntclean:
    probother[i] = math.log(float(othercntclean[i])/sum(othercntclean.values()))

# %%
# read in the test dataset that we'll validate against, and clean the tweets using the function we generatd before
testtweets = pd.read_csv('testtweets.csv', sep='\t')
testtweets['Tweet'] = [cleantext(i) for i in testtweets['Tweet']]

# create an empty list to hold the predicted values for the test tweets
results = []

# %%
# interate through every row in the test tweets dataframe
for index, row in testtweets.iterrows():
    # to hold the summation of the logged probabilities
    appsum = 0
    othersum = 0
    # tokenize the tweets, and iterate through each word
    for word in row.Tweet.split(' '):
        # ignore any token that's shorter than 4 characters
        if len(word) <= 3:
            appsum += 0
            othersum += 0
        # otherwise, look up the word's probability of being an app or an other tweet, and add it up
        # if we've never seen the word before, just assume that we've seen it once before, and add that logged probability to the sum
        else:
            if word in probapp:
                appsum += probapp[word]
            else:
                appsum += math.log(float(1)/sum(appcntclean.values()))
                
            if word in probother:
                othersum += probother[word]
            else:
                othersum += math.log(float(1)/sum(othercntclean.values()))
    # if the sum of the logged probabilities for app is greater than other, than we'll predict it's an App
    if appsum > othersum:
        results.append('App')
    # otherwise we'll predict that it's an Other
    else:
        results.append('Other')

# %%
testtweets['Prediction'] = results

# %%
testtweets
# Out:
#     Number  Class                                              Tweet  \
# 0        1    APP  just love @mandrillapp transactional email ser...
# 1        2    APP  @rossdeane mind submitting a request at http:/...
# 2        3    APP  @veroapp any chance you'll be adding mandrill ...
# 3        4    APP  @elie__ @camj59 jparle de relai smtp 1 million...
# 4        5    APP  would like to send emails for welcome  passwor...
# 5        6    APP  from coworker about using mandrill "i would en...
# 6        7    APP  @mandrill realised i did that about 5 seconds ...
# 7        8    APP       holy shit it’s here http://www.mandrill.com/
# 8        9    APP  our new subscriber profile page activity timel...
# 9       10    APP  @mandrillapp increases scalability ( http://bi...
# 10      11  OTHER  the beets  rt @missmya #nameanamazingband mand...
# 11      12  OTHER  rt @luissand0val fernando vargas mandrill mexi...
# 12      13  OTHER  photo oculi-ds mandrill by natalie manuel http...
# 13      14  OTHER  @mandrill me neither    we can be :sadpanda to...
# 14      15  OTHER  @mandrill n  / ( k  * ( n  - k  ) ) where n = ...
# 15      16  OTHER  megaman x - spark mandrill acapella http://you...
# 16      17  OTHER  @angeluserrare1 storm eagle ftw     nomás no d...
# 17      18  OTHER  gostei de um vídeo @youtube http://youtu.be/xz...
# 18      19  OTHER  what is 2-year-old mandrill  jj  thinking in t...
# 19      20  OTHER  120 years of moscow zoo - mandrill -          ...
#
#    Prediction
# 0         App
# 1         App
# 2         App
# 3         App
# 4         App
# 5         App
# 6         App
# 7         App
# 8         App
# 9         App
# 10      Other
# 11      Other
# 12      Other
# 13      Other
# 14      Other
# 15      Other
# 16      Other
# 17      Other
# 18        App
# 19      Other
